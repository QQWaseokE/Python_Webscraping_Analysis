# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid' : 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

# requests 모듈을 사용해서 http 통신
res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code)
print(res.ok)
if res.ok:
    # 소스보기 텍스트 가져오기
    html = res.text
    # parsing을 하귀 위해서 BeautifulSoup 객체생성
    soup = BeautifulSoup(html, "html.parser")
    # print(type(soup))
    '''
        <div class='sa_text'>
            <a href='https://n.news.naver.com/mnews/article/092/030029302' class='sa_text_title'>
                <strong class="sa_text_strong">엔씨소프트, 2분기 영업익 88억...실적 개선 박차</strong>
    '''
    # print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article']"))) 88개
    # print(len(soup.select("div.sa_text a.sa_text_title"))) 44개
    atag_list = soup.select("div.sa_text a.sa_text_title")
    # print(type(atag_list))
    for atag in atag_list:
        # text속성 : tag사이의 content, strip() : 공백제거
        title = atag.text.strip()
        # href 속성의 값을 추출하기
        url = atag['href']
        print(f'news 제목 = {title}')
        print(f'링크 = {url}')
        print('----------')

else:
    print(f'Error 발생 {res.status_code}')
# Out:
# https://news.naver.com/section/105
# <class 'requests.models.Response'>
# 200
# True
# news 제목 = 데브시스터즈, 2분기 영업익 49억원…"연내 '쿠키런' 인도 진출로 매출 확대"
# 링크 = https://n.news.naver.com/mnews/article/003/0012712051
# ----------
# news 제목 = 우주항공청 하반기 채용 시작…'찾아가는 채용설명회' 개최
# 링크 = https://n.news.naver.com/mnews/article/008/0005073553
# ----------
# news 제목 = 낯선 이 작물이 파킨슨병 효과 `수퍼푸드`?...국산 신품종 1호  나왔다
# 링크 = https://n.news.naver.com/mnews/article/029/0002893041
# ----------
# news 제목 = SKT, 2분기 영업익 5375억원…전년비 16%↑
# 링크 = https://n.news.naver.com/mnews/article/215/0001174047
# ----------
# news 제목 = '7777'·'1004' 잡아라…KT, 선호번호 1만 개 추첨
# 링크 = https://n.news.naver.com/mnews/article/055/0001179036
# ----------
# news 제목 = 스타벅스-카카오, 대학생 전용 혜택 프로그램 선보인다
# 링크 = https://n.news.naver.com/mnews/article/029/0002893052
# ----------
# news 제목 = 신유빈·안세영·김우민 등 '팀 갤럭시' 선수들 삼성 올림픽 체험관 방문
# 링크 = https://n.news.naver.com/mnews/article/366/0001010068
# ----------
# news 제목 = NHN, 2분기 영업이익 285억원…전년比 36.3%↑
# 링크 = https://n.news.naver.com/mnews/article/008/0005073406
# ----------
# news 제목 = 길거리 해메던 90대 노인, 집배원이 구했다
# 링크 = https://n.news.naver.com/mnews/article/138/0002179309
# ----------
# news 제목 = TI, 세계 최초 마그네틱 패키징 적용 '초소형 전력모듈' 출시
# 링크 = https://n.news.naver.com/mnews/article/092/0002341074
# ----------
# news 제목 = “몽골 사막·中 톄산산맥 적설” 韓 역대급 폭염, 큰 영향 끼쳤다
# 링크 = https://n.news.naver.com/mnews/article/016/0002346061
# ----------
# news 제목 = 셀트리온 `프롤리아` 시밀러 CT-P41 "3상서 유효성·안전성 확인"
# 링크 = https://n.news.naver.com/mnews/article/029/0002893131
# ----------
# news 제목 = 정부, 방송 4법 재의요구안 의결...대통령 재가시 다시 국회로
# 링크 = https://n.news.naver.com/mnews/article/092/0002341072
# ----------
# news 제목 = “상급종합병원, 중증환자 60%까지…전문인력 중심으로 전환”
# 링크 = https://n.news.naver.com/mnews/article/366/0001010146
# ----------
# news 제목 = 넷마블 신작 ‘7대죄 키우기’, 하반기 실적 견인 기대감
# 링크 = https://n.news.naver.com/mnews/article/009/0005346067
# ----------
# news 제목 = SK텔레콤, 성장 정체 속 실적 방어…'AI 수익화' 더 힘준다
# 링크 = https://n.news.naver.com/mnews/article/629/0000310904
# ----------
# news 제목 = “폭발위험 차단 전고체전지” 韓 연구진, 설계 방법론 최초 제시
# 링크 = https://n.news.naver.com/mnews/article/016/0002346046
# ----------
# news 제목 = '한국인 최초 세계은행 부총재' 김상부 "韓 정부·기업과 협력 중요"
# 링크 = https://n.news.naver.com/mnews/article/014/0005223880
# ----------
# news 제목 = 한밤중 거리 헤매던 노인 구한 ‘천사 집배원’
# 링크 = https://n.news.naver.com/mnews/article/366/0001010143
# ----------
# news 제목 = 한밤중 거리 헤매던 90대 국가유공자, 우체국 집배원이 구했다
# 링크 = https://n.news.naver.com/mnews/article/031/0000859645
# ----------
# news 제목 = 중국산 과잉재고에 국내 배터리 업계 '이중고'
# 링크 = https://n.news.naver.com/mnews/article/030/0003229480
# ----------
# news 제목 = 중국産 재고가 몰려온다..."저가공세 돌파구 찾아야"
# 링크 = https://n.news.naver.com/mnews/article/092/0002341069
# ----------
# news 제목 = 김상부 세계은행 부총재 "저소득국에도 AI 혜택 돌아가게 할 것"
# 링크 = https://n.news.naver.com/mnews/article/003/0012712515
# ----------
# news 제목 = "상급종합병원 중증환자 비중 60%까지 상향"…전문인력 중심 전환 박차
# 링크 = https://n.news.naver.com/mnews/article/421/0007713224
# ----------
# news 제목 = 티메프 사태에 입 연 네이버 CFO "제도 문제 아닌 경영 실패"
# 링크 = https://n.news.naver.com/mnews/article/003/0012712462
# ----------
# news 제목 = “그린란드 빙상, 110만년전엔 녹색 툰드라였다”
# 링크 = https://n.news.naver.com/mnews/article/021/0002652725
# ----------
# news 제목 = '결제서비스 약진' NHN…"티몬 채권 회수 주력"(종합)
# 링크 = https://n.news.naver.com/mnews/article/421/0007713205
# ----------
# news 제목 = 엔씨소프트-텐센트, ‘블레이드앤소울2’ 中 2차 CBT 진행
# 링크 = https://n.news.naver.com/mnews/article/119/0002859192
# ----------
# news 제목 = "공영방송 이사 선임 논란 확인"…野 과방위, 방통위 현장검증
# 링크 = https://n.news.naver.com/mnews/article/421/0007713145
# ----------
# news 제목 = 삼성전자, 업계 최저 0.65㎜ 두께 LPDDR5X 개발
# 링크 = https://n.news.naver.com/mnews/article/022/0003957543
# ----------
# news 제목 = 이스라엘-헤즈볼라 전투서도 부각된 ‘드론 무기’…우리나라는?
# 링크 = https://n.news.naver.com/mnews/article/138/0002179295
# ----------
# news 제목 = [종합] NHN클라우드 "돈 벌 일만 남았다"…올 연말 공공·민간 사업 순항
# 링크 = https://n.news.naver.com/mnews/article/092/0002341061
# ----------
# news 제목 = 폭발·화재 없는 전고체전지 상용화 앞당길 '설계 도구' 개발
# 링크 = https://n.news.naver.com/mnews/article/584/0000028188
# ----------
# news 제목 = 개미와 벌처럼 사회적 군집 이루는 기생충도 있다 [와우! 과학]
# 링크 = https://n.news.naver.com/mnews/article/081/0003470273
# ----------
# news 제목 = “재유행 조짐 코로나19”…‘인공 폐’로 치료제 개발 속도낸다
# 링크 = https://n.news.naver.com/mnews/article/016/0002345936
# ----------
# news 제목 = "우연히 시작한 '로봇 손' 연구…안전한 로봇과 공존 고민하게 됐죠"
# 링크 = https://n.news.naver.com/mnews/article/092/0002341060
# ----------
# news 제목 = 방통위 방문한 과방위 野 "KBS·방문진 이사 선임 불법 입증할 것"
# 링크 = https://n.news.naver.com/mnews/article/031/0000859620
# ----------
# news 제목 = 과방위, 방통위 현장방문…"공영방송 이사 선임 불법성 검증할 것" [현장]
# 링크 = https://n.news.naver.com/mnews/article/138/0002179291
# ----------
# news 제목 = NHN, 본업 견조하지만…티몬·위메프 사태 ‘골치’
# 링크 = https://n.news.naver.com/mnews/article/119/0002859142
# ----------
# news 제목 = 데브시스터즈, '쿠키런' 업고 2Q 흑자전환
# 링크 = https://n.news.naver.com/mnews/article/293/0000057107
# ----------
# news 제목 = NHN "티메프 사태로 102억원 대손 인식…채권 회수 노력"
# 링크 = https://n.news.naver.com/mnews/article/003/0012712143
# ----------
# news 제목 = "무슨 일 할까?"…中 기밀 우주선, 14인치 망원경에 포착 [영상]
# 링크 = https://n.news.naver.com/mnews/article/092/0002341055
# ----------
# news 제목 = SKT, 로밍·데이터센터 효과 톡톡…2분기 영업익 16% 증가(종합)
# 링크 = https://n.news.naver.com/mnews/article/003/0012712113
# ----------
# news 제목 = "AI·데이터센터·클라우드 약진"…SK텔레콤 2Q 영업이익 16%↑
# 링크 = https://n.news.naver.com/mnews/article/008/0005073480
# ----------

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
    'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    # requests 모듈을 사용해서 http 통신
    res = requests.get(url, headers=req_header)
    if res.ok:
        # 소스보기 텍스트 가져오기
        html = res.text
        # parsing을 하귀 위해서 BeautifulSoup 객체생성
        soup = BeautifulSoup(html, "html.parser")
        atag_list = soup.select("div.sa_text a.sa_text_title")
        for atag in atag_list:
            # text속성 : tag사이의 content, strip() : 공백제거
            title = atag.text.strip()
            # href 속성의 값을 추출하기
            url = atag['href']
            print(f'news 제목 = {title}')
            print(f'링크 = {url}')
            print('----------')
    
    else:
        print(f'Error 발생 {res.status_code}')

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
print_news(103,section_dict[103])
# Out:
# ======> https://news.naver.com/section/103 생활/문화 뉴스 <======
# news 제목 = 공공도서관 이용자 지속 증가…"수도권·광역시 도서관 더 필요"
# 링크 = https://n.news.naver.com/mnews/article/421/0007712567
# ----------
# news 제목 = 메르세데스 AMG가 인정한 성능…GT 쿠페 신차에 한국타이어 장착
# 링크 = https://n.news.naver.com/mnews/article/421/0007712505
# ----------
# news 제목 = 전국 곳곳 소나기…체감온도 35도 안팎 무더위 계속[930 날씨]
# 링크 = https://n.news.naver.com/mnews/article/056/0011775769
# ----------
# news 제목 = 폭스바겐코리아, 프리미엄 SUV '신형 투아렉' 국내 상륙[머니S픽]
# 링크 = https://n.news.naver.com/mnews/article/417/0001019102
# ----------
# news 제목 = 브로드웨이 마법을 서울로… ‘알라딘’ 韓초연 캐스팅도 역대급
# 링크 = https://n.news.naver.com/mnews/article/023/0003850834
# ----------
# news 제목 = 기록적 폭염에 폭우까지…전국 곳곳서 정전 등 피해 속출
# 링크 = https://n.news.naver.com/mnews/article/081/0003470285
# ----------
# news 제목 = 두 달 연속 신장세 르노코리아...'그랑 콜레오스'로 부스터 달까
# 링크 = https://n.news.naver.com/mnews/article/008/0005073110
# ----------
# news 제목 = 국립현대미술관 정영선 전시 디자인, 독일 레드닷 디자인상 받아
# 링크 = https://n.news.naver.com/mnews/article/055/0001179095
# ----------
# news 제목 = [날씨] 한낮 서울 33도·경산 36도…요란한 소나기 유의
# 링크 = https://n.news.naver.com/mnews/article/422/0000674942
# ----------
# news 제목 = [날씨] 서울 14일째 '폭염 특보'...전국 한증막 더위 속 강한 소나기
# 링크 = https://n.news.naver.com/mnews/article/052/0002070775
# ----------
# news 제목 = '풍덩' 다이빙하다 다쳤다, 올바른 응급 처치 방법은?
# 링크 = https://n.news.naver.com/mnews/article/346/0000078471
# ----------
# news 제목 = 전미라, 발바닥 물집에 바느질을? "물도 마르고 잘 아물어"
# 링크 = https://n.news.naver.com/mnews/article/296/0000080578
# ----------
# news 제목 = 폭스바겐코리아 대표 "디젤차 수요 여전히 많다"...신형 투아렉 디젤 공개 [FN 모빌리티]
# 링크 = https://n.news.naver.com/mnews/article/014/0005223903
# ----------
# news 제목 = 사막 달리고 보잉747 끌던 VW 투아렉…새 얼굴로 韓 복귀
# 링크 = https://n.news.naver.com/mnews/article/092/0002341076
# ----------
# news 제목 = “이 맛에 살 뺀다?”…입맛·기분 좋아지고 성욕도 ‘쑥’
# 링크 = https://n.news.naver.com/mnews/article/296/0000080577
# ----------
# news 제목 = 무섭게 퍼붓는다…폭염 속 시간당 100㎜ '극한 소나기'
# 링크 = https://n.news.naver.com/mnews/article/422/0000674933
# ----------
# news 제목 = ‘비행기 끌고 다카르 랠리 우승’… 폭스바겐, 플래그십 SUV ‘투아렉’ 출시
# 링크 = https://n.news.naver.com/mnews/article/366/0001010148
# ----------
# news 제목 = [날씨] 전국 폭염 계속…밤까지 경기 동부 등 80mm↑ 소나기
# 링크 = https://n.news.naver.com/mnews/article/055/0001179133
# ----------
# news 제목 = [오후날씨 꿀팁] 폭염 속 곳곳에 시간당 30~50mm 강한 소나기
# 링크 = https://n.news.naver.com/mnews/article/056/0011775897
# ----------
# news 제목 = [센터웨더] 찜통 속 폭우…열대야, 역대 최다 기록할 듯
# 링크 = https://n.news.naver.com/mnews/article/422/0000674924
# ----------
# news 제목 = "흙 속에 살더니, 아내가 건강해졌어요"
# 링크 = https://n.news.naver.com/mnews/article/047/0002442120
# ----------
# news 제목 = 비행기도 끄는 SUV…폭스바겐 신형 '투아렉' 출시
# 링크 = https://n.news.naver.com/mnews/article/215/0001174066
# ----------
# news 제목 = [날씨]  찜통더위 계속‥내륙 강한 소나기 주의
# 링크 = https://n.news.naver.com/mnews/article/214/0001366129
# ----------
# news 제목 = 끝을 모르는 폭염, 8일까지 전국 곳곳에 소나기
# 링크 = https://n.news.naver.com/mnews/article/032/0003313223
# ----------
# news 제목 = 축구하다가 ‘이 증상’ 때문에 고환암 발견… 英 20대 남성, 사연 봤더니?
# 링크 = https://n.news.naver.com/mnews/article/346/0000078467
# ----------
# news 제목 = 마블 출연 유명 女배우, 운동으로 20년 전 몸매 만들어 화제… 비결 확인하니?
# 링크 = https://n.news.naver.com/mnews/article/346/0000078466
# ----------
# news 제목 = '전자발찌 1호' 고영욱, 유튜브로 복귀? "부끄러운 삶 살았다"
# 링크 = https://n.news.naver.com/mnews/article/079/0003925095
# ----------
# news 제목 = [날씨] 찜통더위 속 강한 소나기…돌풍·벼락 동반
# 링크 = https://n.news.naver.com/mnews/article/422/0000674910
# ----------
# news 제목 = 전일 역대급 폭락에도 상한가 기록한 '이 종목'… "업계 최초 성과"
# 링크 = https://n.news.naver.com/mnews/article/011/0004376596
# ----------
# news 제목 = 카미유 보며 느낀 점, 내 인생 주인은 나라는 것
# 링크 = https://n.news.naver.com/mnews/article/047/0002442099
# ----------
# news 제목 = 경쟁사와 같은 물건에 쿠폰만 더 얹어 밑지는 장사…욕심으로 얼룩진 큐텐의 ‘IPO 사기극’ [충무로에서]
# 링크 = https://n.news.naver.com/mnews/article/009/0005346039
# ----------
# news 제목 = 폭염에 갑자기 쏟아진 비…더운데 침수에 정전 피해까지
# 링크 = https://n.news.naver.com/mnews/article/015/0005018592
# ----------
# news 제목 = 알고보니 고혈압 주범…플라스틱병 생수의 배신
# 링크 = https://n.news.naver.com/mnews/article/020/0003580507
# ----------
# news 제목 = 中정치학자 "中-美 중산층 공생적 경제관계…美중산층에도 이익"
# 링크 = https://n.news.naver.com/mnews/article/001/0014857538
# ----------
# news 제목 = 77세 마라토너 원지상씨, 미 대륙 횡단 마라톤 성공
# 링크 = https://n.news.naver.com/mnews/article/047/0002442095
# ----------
# news 제목 = 고영욱, "무기력한 일상 벗어나고자"...유튜브 개설에 대중 싸늘
# 링크 = https://n.news.naver.com/mnews/article/052/0002070712
# ----------
# news 제목 = [단독] 민자도로 통행료 '반값'했더니…화물차 60%↑ 속도 6%↓
# 링크 = https://n.news.naver.com/mnews/article/025/0003378137
# ----------
# news 제목 = [김태열의 생생건강S펜]  "이 없으면 잇몸으로 때우면 생기는 최악의 결과는?"
# 링크 = https://n.news.naver.com/mnews/article/016/0002345929
# ----------
# news 제목 = '반갈샷'으로 5000만개 팔리더니…'우유생크림떡' 나왔다
# 링크 = https://n.news.naver.com/mnews/article/015/0005018574
# ----------
# news 제목 = "김교신의 꿈, '김치 냄새 나는 조선기독교 만들자' 였다"
# 링크 = https://n.news.naver.com/mnews/article/047/0002442088
# ----------
# news 제목 = 오늘도 35도 폭염…소나기 강하고 일부 호우주의보
# 링크 = https://n.news.naver.com/mnews/article/629/0000310846
# ----------
# news 제목 = [날씨] 서울 16일, 강릉 18일 연속 열대야…곳곳 요란한 소나기
# 링크 = https://n.news.naver.com/mnews/article/422/0000674903
# ----------
# news 제목 = 셀트리온, 골다공증 치료제 'CT-P41' 유효성·안전성 확인
# 링크 = https://n.news.naver.com/mnews/article/421/0007712815
# ----------
# news 제목 = [아침뉴스타임 날씨] 곳곳에 강한 소나기…체감온도 35도 안팎 폭염 계속
# 링크 = https://n.news.naver.com/mnews/article/056/0011775796
# ----------

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}
# jpg filename lsit
img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        # binary 데이터 추출
        img_data = res.content
        # url에서 file name을 가져오기
        file_name = os.path.basename(img_url)
        with open(file_name, 'wb') as file:
            print(f'writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error 발생 {res.status_code}')
# Out:
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg (299,319 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg (163,333 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg (182,530 bytes)

# %% [markdown]
# * 현재 요청된 페이지(특정 회차)의 image 모두 다운로드 해보기

# %%
import requests
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=817945&no=37&week=mon'
req_header = {
    'referer': webtoon_url
}
# jpg image 파일명을 먼저 알아내기
res = requests.get(webtoon_url)
if res.ok: #200
    # xxx.jpg 파일명 목록 가져오기
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']"))) # 108개
    print(len(soup.select("img[src*='IMAG01']"))) # 18개 <- 채택
    img_tag_list = soup.select("img[src*='IMAG01']")
    
    # image 파일명을 저장할 리스트 선언
    img_url_list = []
    for img_tag in img_tag_list:
        '''
            <img src="https://image-comic.pstatic.net/webtoon/817945/37/_IMAG01_1.jpg"/>
        '''
        # print(img_tag['src'])
        # image 태그의 src속성의 값을 추출해서 list에 추가하기
        # ['http://x1.jpg', 'http://x2.jpg']
        img_url_list.append(img_tag['src'])
    
    image_dir_name = 'img'
    # img 디렉토리가 없으면 img 디렉토리 생성하기
    if not os.path.isdir(image_dir_name):
        os.mkdir(image_dir_name)

    for idx, img_url in enumerate(img_url_list, 1):
        # print(idx, img_url)
        res = requests.get(img_url, headers=req_header)
        print(idx, res.status_code)
        if res.ok:
            # binary 데이터 추출
            img_data = res.content
            # url에서 file name을 가져오기
            file_name = os.path.basename(img_url)
            # img/xxx.jpg
            dir_name = os.path.join(image_dir_name, file_name)
            with open(dir_name, 'wb') as file:
                print(f'writing to {dir_name} ({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error 발생 {res.status_code}')
            
else:
    print(res.status_code)
# Out:
# 102
# 18
# 1 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_1.jpg (128,897 bytes)
# 2 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_2.jpg (143,194 bytes)
# 3 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_3.jpg (101,900 bytes)
# 4 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_4.jpg (112,007 bytes)
# 5 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_5.jpg (190,876 bytes)
# 6 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_6.jpg (134,590 bytes)
# 7 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_7.jpg (132,910 bytes)
# 8 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_8.jpg (174,434 bytes)
# 9 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_9.jpg (88,576 bytes)
# 10 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_10.jpg (177,240 bytes)
# 11 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_11.jpg (95,130 bytes)
# 12 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_12.jpg (109,718 bytes)
# 13 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_13.jpg (144,476 bytes)
# 14 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_14.jpg (127,739 bytes)
# 15 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_15.jpg (143,133 bytes)
# 16 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_16.jpg (159,328 bytes)
# 17 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_17.jpg (139,300 bytes)
# 18 200
# writing to img/20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_18.jpg (54,967 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-"

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
